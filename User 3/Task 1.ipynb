# %%
import pandas as pd

# %%
path = 'task1_datast.xlsx'
data = pd.read_excel(path)
data.head()
# Out:
#      WHO status ISO_3 country name         Country name  Population  \
# 0  Member State                AFG          Afghanistan    40099462
# 1  Member State                ALB              Albania     2854710
# 2  Member State                DZA              Algeria    44177969
# 3  Member State                ATG  Antigua and Barbuda       93219
# 4  Member State                ARG            Argentina    45276780
#
#           Income group                    WHO Region  \
# 0           Low income  Eastern Mediterranean Region
# 1  Upper middle income               European Region
# 2  Lower middle income                African Region
# 3          High income        Region of the Americas
# 4  Upper middle income        Region of the Americas
#
#    GRSSR participation 2009  GRSSR participation 2013  \
# 0                    2009.0                    2013.0
# 1                    2009.0                    2013.0
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                    2009.0                    2013.0
#
#    GRSSR participation 2015  GRSSR participation 2018  ...  \
# 0                    2015.0                    2018.0  ...
# 1                    2015.0                    2018.0  ...
# 2                    2015.0                       NaN  ...
# 3                    2015.0                    2018.0  ...
# 4                    2015.0                    2018.0  ...
#
#    Year WHO-estimated road traffic fatalities (Update)  \
# 0                                               2010
# 1                                               2010
# 2                                               2010
# 3                                               2010
# 4                                               2010
#
#    2010 WHO-estimated road traffic fatalities (update)  \
# 0                                             5546.0
# 1                                              388.0
# 2                                             8039.0
# 3                                                5.0
# 4                                             5252.0
#
#    2010 Lower bound WHO-estimated road traffic fatalities (update)  \
# 0                                             4764.0
# 1                                              364.0
# 2                                             7231.0
# 3                                                5.0
# 4                                             4976.0
#
#    2010 Upper bound WHO-estimated road traffic fatalities (update)  \
# 0                                             6328.0
# 1                                              412.0
# 2                                             8848.0
# 3                                                5.0
# 4                                             5528.0
#
#    2010 WHO-estimated rate per 100 000 population (update)  \
# 0                                               19.7
# 1                                               13.3
# 2                                               22.4
# 3                                                5.8
# 4                                               12.8
#
#    Year WHO-estimated road traffic fatalities (Update).1  \
# 0                                               2016
# 1                                               2016
# 2                                               2016
# 3                                               2016
# 4                                               2016
#
#    2016 WHO-estimated road traffic fatalities (update)  \
# 0                                             7106.0
# 1                                              370.0
# 2                                             8536.0
# 3                                                8.0
# 4                                             5755.0
#
#    2016 Lower bound WHO-estimated road traffic fatalities (update)  \
# 0                                             6228.0
# 1                                              344.0
# 2                                             7558.0
# 3                                                7.0
# 4                                             5435.0
#
#    2016 Upper bound WHO-estimated road traffic fatalities (update)  \
# 0                                             7984.0
# 1                                              395.0
# 2                                             9514.0
# 3                                                9.0
# 4                                             6075.0
#
#    2016 WHO-estimated rate per 100 000 population (update)
# 0                                               20.5
# 1                                               12.8
# 2                                               21.2
# 3                                                8.8
# 4                                               13.2
#
# [5 rows x 228 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Columns: 228 entries, WHO status to 2016 WHO-estimated rate per 100 000 population (update)
# dtypes: bool(1), float64(85), int64(12), object(130)
# memory usage: 305.3+ KB

# %%
data.shape
# Out:
# (172, 228)

# %%
for col in data.columns:
    print(f"{col}: {data[col].dtype}")
# Out:
# WHO status: object
# ISO_3 country name: object
# Country name: object
# Population: int64
# Income group: object
# WHO Region: object
# GRSSR participation 2009: float64
# GRSSR participation 2013: float64
# GRSSR participation 2015: float64
# GRSSR participation 2018: float64
# GRSSR participation 2013.1: int64
# Reported fatalities: float64
# Year reported fatalities: int64
# Reported fatalities gender distribution  (% Males): float64
# Reported fatalities gender distribution  (%Females): float64
# Reported fatalities user distribution  (% powered light vehicles): float64
# Reported fatalities user distribution  (% powered 2/ wheelers): float64
# Reported fatalities user distribution  (% pedestrian): float64
# Reported fatalities user distribution  (% cyclist): float64
# Reported fatalities user distribution  (% other): float64
# WHO-estimated road traffic fatalities: float64
# Lower bound WHO-estimated road traffic fatalities: float64
# Upper bound WHO-estimated road traffic fatalities: float64
# Year WHO-estimated road traffic fatalities: int64
# WHO-estimated rate per 100 000 population: float64
# National law on universal access to emergency care  : object
# emergency care access legislation not validated: float64
# National law guaranteeing free-of-charge access to rehabilitative care for all injured: object
# Access to rehab care legislation not validated: float64
# National law guaranteeing free-of-charge access to psychological services to road crash victims and their families: object
# Psychological care access legislation not validated: float64
# National good Samaritan law: object
# Good Samaritan law not validated: float64
# National emergency care access number: object
# National target for time between serious crash and initial provision of professional emergency care: object
# Year by National target for time between serious crash and initial provision of professional emergency care (year): float64
# Total paved kilometres (year): float64
# Year total paved kilometres: float64
# Presence of technical standards for new roads that take account of all road-user safety, or align with relevant UN Conventions and regulate compliance with them: object
# On roads technical standards country adheres to corresponding UN or equivalent international safety regulation: float64
# Presence of systematic approaches to assess/audit new roads: object
# National law requiring a formal road safety inspection/assessment: object
# Legislation on road inspection/assessment not validated: float64
# Target for roads to meet technical safety standards for all users: object
# Year by target for roads to meet technical safety standards for all users (year): float64
# Investments to upgrade high risk locations: object
# Total registered vehicles: float64
# Total registered vehicles rate per 100 000 pop: float64
# Cars and 4-wheeled light vehicles: float64
# Powered 2- and 3-wheelers: float64
# Heavy trucks: float64
# Buses: float64
# Other: float64
# Legislation on periodic vehicle technical inspection: object
# On VTI country adheres to corresponding UN or equivalent international safety regulation: float64
# On VTI corresponding EU regulation mandatory for country.: float64
# VTI legislation not validated: float64
# Year total registered vehicles: float64
# Presence of high-quality safety standards for used-vehicle imports/exports 2: object
# National law on front and side impact protection: object
# On front and side impact protection country adheres to corresponding UN or equivalent international safety regulation: float64
# On front and side impact protection corresponding EU regulation mandatory for country.: float64
# Front and side impact protection legislation not validated: float64
# National law on seat belt and seat belt anchorages: object
# Country adheres to corresponding UN or equivalent international safety regulation: float64
# Corresponding EU regulation mandatory for country.: float64
# National law on electronic stability control: object
# On ESC country adheres to corresponding UN or equivalent international safety regulation: float64
# On ESC corresponding EU regulation mandatory for country.: float64
# National law on pedestrian protection: object
# On pedestrian protection country adheres to corresponding UN or equivalent international safety regulation: float64
# On pedestrian protection corresponding EU regulation mandatory for country.: float64
# National law on motorcycle anti-lock braking systems: object
# On ABS country adheres to corresponding UN or equivalent international safety regulation: float64
# On ABS corresponding EU regulation mandatory for country.: float64
# Government vehicle procurement practices include safety prerequisites: object
# Presence of strategies to promote alternatives to individuals' use of powered vehicles: object
# National road safety strategy: object
# Fatality reduction target: object
# Year by fatality reduction target: float64
# Non fatal reduction target (year): object
# Year by non fatal reduction target: float64
# Funding to implement strategy: object
# National legislation mandating third-party liability insurance for powered vehicles: object
# Insurance legislation not validated: float64
# National law on driving time and rest periods for professional drivers: object
# On driving time legislation country adheres to corresponding UN or equivalent international safety regulation: float64
# Unnamed: 87: float64
# On driving time legislation  not validated: float64
# Adhesion to at least one of the 7 UN core vehicle regulations: bool
# Adherence to one or more of the 7 UN road safety conventions: int64
# Presence of national lead agency to implement  national road safety action plan: object
# Presence of agencies that  coordinate pre‐hospital and emergency medical services: object
# Legislation setting appropriate urban speed limits for passenger cars and motorcycles: int64
# Speed legislation not validated: float64
# National law setting a speed limit  : object
# Maximum urban speed limit: object
# Maximum rural speed limit: object
# Maximum motorway speed limit: object
# Local authorities can modify limits: object
# Presence of targets to reduce speeds nationally: object
# Year by targets to reduce speeds nationally: float64
# Available types of enforcement: object
# Legislation on drink driving: int64
# Drink an drive legislation not validated: float64
# Alcohol consumption prohibited in country: float64
# National law on drink-driving: object
# BAC limit – general population: object
# BAC limit – young or novice drivers: object
# Presence of targets to reduce driving after drinking nationally (year): object
# Year by targets to reduce driving after drinking nationally: float64
# Random breath testing carried out: object
# Testing carried out in case of fatal crash: object
# Legislation on drug driving: object
# Drug and diving legislation not validated: float64
# Legislation on distracted driving (mobile phones) while driving: object
# Distracted driving legislation not validated: float64
# Ban on mobile phone use (Hand held): object
# Ban on mobile phone use (Hand free): object
# Presence of targets to reduce distracted driving nationally: object
# Year by targets to reduce distracted driving nationally (year): float64
# Legislation requiring adult motorcycle riders to wear a helmet properly fastened that meets appropriate standards: int64
# Helmet legislation not validated: float64
# National motorcycle helmet law: object
# Legislation requires helmet fastening: object
# Legislation applies to drivers and passengers: object
# Legislation applies to all road types: object
# Legislation applies to all engine types: object
# Legislation refers to and/or specifies helmet standard: object
# Helmet standard adheres to corresponding UN or equivalent international safety regulation: float64
# Helmet standard corresponding EU regulation mandatory for country.: float64
# Presence of targets to increase helmet use: object
# Year by target to increase helmet use: float64
# Helmet wearing rate (%Driver): float64
# Helmet wearing rate (% Passenger): object
# Minimum age/height children are allowed as passengers on motorcycles nationally: object
# Legislation on the use of seat belts for all motor vehicle occupants (UNVTI 8a): int64
# Seat belt legislation not validated: float64
# National seat-belt law: object
# Legislation applies to front and rear seat occupants: object
# Presence of targets to increase seat belt use: object
# Year by target to increase seat belt use (year): float64
# Seat-belt wearing rate  (% Drivers): float64
# Seat-belt wearing rate (% front seat occupants): float64
# Seat-belt wearing rate  (% rear seat occupants): float64
# Legislation requiring the use of child safety restraint systems that meet appropriate standards: int64
# CRS legislation not validated: float64
# National child restraints use law: object
# Children seated in front seat: object
# Age or height specified for children requiring child restraint: object
# Child restraint standard referred to and/or specified: object
# CRS standard adheres to corresponding UN or equivalent international safety regulation: float64
# CRS standard corresponding EU regulation mandatory for country.: float64
# Presence of targets to increase child safety restraint use: object
# Year by targets to increase child safety restraint use: float64
# Civil Registration and Vital Statistics level: object
# Evolution of frequency and distribution of journeys by modal type: object
# Speeding violations and speeding‐related injuries and fatalities: object
# Driving under the influence of alcohol or drugs  and related road traffic‐related fatalities and injuries: object
# Seat belt  and child-restraint systems use: object
# Powered 2- and 3- wheeler helmet use: object
# Mobile phone use while driving: object
# Evolution of population: object
# Evolution of income group: object
# Evolution of reported fatalities: object
# Evolution of WHO-estimated fatalities: object
# Evolution of WHO-estimated fatality rate: object
# Evolution of presence of systematic approaches to assess/audit new roads: object
# Evolution of investments to upgrade high risk locations: object
# Evolution of total registered vehicles: object
# Evolution of cars and 4-wheeled light vehicles: object
# Evolution of powered 2- and 3-wheelers: object
# Evolution of heavy trucks: object
# Evolution of buses: object
# Evolution of other: object
# Evolution of national emergency care access number: object
# Evolution of strategies to promote alternatives to individuals' use of powered vehicles: object
# Evolution of National road safety strategy: object
# Evolution of fatality reduction target: object
# Evolution of non fatal reduction target: object
# Evolution of national lead agency to implement  national road safety action plan: object
# Evolution Legislation setting appropriate urban speed limits for passenger cars and motorcycles: object
# Evolution of national law setting a speed limit  : object
# Evolution of maximum urban speed limit: object
# Evolution of maximum rural speed limit: object
# Evolution of maximum motorway speed limit: object
# Evolution of whether local authorities can modify limits: object
# Evolution of available types of enforcement: object
# Evolution of legislation on drink driving: object
# Evolution of national law on drink-driving: object
# Evolution of BAC limit – general population: object
# Evolution of BAC limit – young or novice drivers: object
# Evolution of Random breath testing carried out: object
# Evolution of Testing carried out in case of fatal crash: object
# Evolution of Legislation on drug driving: object
# Evolution of Legislation on distracted driving (mobile phones) while driving: object
# Evolution on ban on mobile phone use: object
# Evolution of Legislation requiring adult motorcycle riders to wear a helmet properly fastened that meets appropriate standards: object
# Evolution of National motorcycle helmet law: object
# Evolution of presence of targets to reduce driving after drinking nationally: object
# Evolution of legislation applies to drivers and passengers: object
# Evolution of legislation applies to all road types: object
# Evolution of legislation applies to all engine types: object
# Evolution of legislation refers to and/or specifies helmet standard: object
# Evolution of Helmet wearing rate: object
# Evolution of minimum age/height children are allowed as passengers on motorcycles nationally: object
# Evolution of legislation on the use of seat belts for all motor vehicle occupants: object
# Evolution of national seat-belt law: object
# Evolution of legislation applies to front and rear seat occupants: object
# Evolution of seat-belt wearing rate: object
# Evolution of legislation requiring the use of child safety restraint systems that meet appropriate standards: object
# Evolution of national child restraints use law: object
# Evolution of children seated in front seat: object
# Evolution of age or height specified for children requiring child restraint: object
# Evolution of child restraint standard referred to and/or specified: object
# Evolution in Civil Registration and Vital Statistics qualification: object
# Item not collected before: float64
# Evolution in adhesion UN conventions: object
# Year WHO-estimated road traffic fatalities (Update): int64
# 2010 WHO-estimated road traffic fatalities (update): float64
# 2010 Lower bound WHO-estimated road traffic fatalities (update): float64
# 2010 Upper bound WHO-estimated road traffic fatalities (update): float64
# 2010 WHO-estimated rate per 100 000 population (update): float64
# Year WHO-estimated road traffic fatalities (Update).1: int64
# 2016 WHO-estimated road traffic fatalities (update): float64
# 2016 Lower bound WHO-estimated road traffic fatalities (update): float64
# 2016 Upper bound WHO-estimated road traffic fatalities (update): float64
# 2016 WHO-estimated rate per 100 000 population (update): float64

# %%
for col in data.columns:
    print(f"{col}--> {data[col].isnull().sum()}")
# Out:
# WHO status--> 0
# ISO_3 country name--> 0
# Country name--> 0
# Population--> 0
# Income group--> 3
# WHO Region--> 0
# GRSSR participation 2009--> 12
# GRSSR participation 2013--> 8
# GRSSR participation 2015--> 8
# GRSSR participation 2018--> 10
# GRSSR participation 2013.1--> 0
# Reported fatalities--> 1
# Year reported fatalities--> 0
# Reported fatalities gender distribution  (% Males)--> 38
# Reported fatalities gender distribution  (%Females)--> 39
# Reported fatalities user distribution  (% powered light vehicles)--> 23
# Reported fatalities user distribution  (% powered 2/ wheelers)--> 27
# Reported fatalities user distribution  (% pedestrian)--> 23
# Reported fatalities user distribution  (% cyclist)--> 27
# Reported fatalities user distribution  (% other)--> 24
# WHO-estimated road traffic fatalities--> 1
# Lower bound WHO-estimated road traffic fatalities--> 2
# Upper bound WHO-estimated road traffic fatalities--> 2
# Year WHO-estimated road traffic fatalities--> 0
# WHO-estimated rate per 100 000 population--> 1
# National law on universal access to emergency care  --> 55
# emergency care access legislation not validated--> 116
# National law guaranteeing free-of-charge access to rehabilitative care for all injured--> 44
# Access to rehab care legislation not validated--> 128
# National law guaranteeing free-of-charge access to psychological services to road crash victims and their families--> 60
# Psychological care access legislation not validated--> 112
# National good Samaritan law--> 67
# Good Samaritan law not validated--> 105
# National emergency care access number--> 27
# National target for time between serious crash and initial provision of professional emergency care--> 136
# Year by National target for time between serious crash and initial provision of professional emergency care (year)--> 118
# Total paved kilometres (year)--> 52
# Year total paved kilometres--> 51
# Presence of technical standards for new roads that take account of all road-user safety, or align with relevant UN Conventions and regulate compliance with them--> 11
# On roads technical standards country adheres to corresponding UN or equivalent international safety regulation--> 111
# Presence of systematic approaches to assess/audit new roads--> 19
# National law requiring a formal road safety inspection/assessment--> 3
# Legislation on road inspection/assessment not validated--> 169
# Target for roads to meet technical safety standards for all users--> 45
# Year by target for roads to meet technical safety standards for all users (year)--> 110
# Investments to upgrade high risk locations--> 28
# Total registered vehicles--> 36
# Total registered vehicles rate per 100 000 pop--> 36
# Cars and 4-wheeled light vehicles--> 74
# Powered 2- and 3-wheelers--> 66
# Heavy trucks--> 73
# Buses--> 73
# Other--> 105
# Legislation on periodic vehicle technical inspection--> 22
# On VTI country adheres to corresponding UN or equivalent international safety regulation--> 158
# On VTI corresponding EU regulation mandatory for country.--> 146
# VTI legislation not validated--> 172
# Year total registered vehicles--> 14
# Presence of high-quality safety standards for used-vehicle imports/exports 2--> 13
# National law on front and side impact protection--> 43
# On front and side impact protection country adheres to corresponding UN or equivalent international safety regulation--> 132
# On front and side impact protection corresponding EU regulation mandatory for country.--> 146
# Front and side impact protection legislation not validated--> 147
# National law on seat belt and seat belt anchorages--> 39
# Country adheres to corresponding UN or equivalent international safety regulation--> 125
# Corresponding EU regulation mandatory for country.--> 146
# National law on electronic stability control--> 42
# On ESC country adheres to corresponding UN or equivalent international safety regulation--> 114
# On ESC corresponding EU regulation mandatory for country.--> 146
# National law on pedestrian protection--> 43
# On pedestrian protection country adheres to corresponding UN or equivalent international safety regulation--> 114
# On pedestrian protection corresponding EU regulation mandatory for country.--> 146
# National law on motorcycle anti-lock braking systems--> 40
# On ABS country adheres to corresponding UN or equivalent international safety regulation--> 121
# On ABS corresponding EU regulation mandatory for country.--> 146
# Government vehicle procurement practices include safety prerequisites--> 46
# Presence of strategies to promote alternatives to individuals' use of powered vehicles--> 27
# National road safety strategy--> 8
# Fatality reduction target--> 65
# Year by fatality reduction target--> 59
# Non fatal reduction target (year)--> 93
# Year by non fatal reduction target--> 88
# Funding to implement strategy--> 60
# National legislation mandating third-party liability insurance for powered vehicles--> 22
# Insurance legislation not validated--> 150
# National law on driving time and rest periods for professional drivers--> 22
# On driving time legislation country adheres to corresponding UN or equivalent international safety regulation--> 127
# Unnamed: 87--> 146
# On driving time legislation  not validated--> 150
# Adhesion to at least one of the 7 UN core vehicle regulations--> 0
# Adherence to one or more of the 7 UN road safety conventions--> 0
# Presence of national lead agency to implement  national road safety action plan--> 0
# Presence of agencies that  coordinate pre‐hospital and emergency medical services--> 35
# Legislation setting appropriate urban speed limits for passenger cars and motorcycles--> 0
# Speed legislation not validated--> 170
# National law setting a speed limit  --> 2
# Maximum urban speed limit--> 14
# Maximum rural speed limit--> 22
# Maximum motorway speed limit--> 45
# Local authorities can modify limits--> 4
# Presence of targets to reduce speeds nationally--> 27
# Year by targets to reduce speeds nationally--> 106
# Available types of enforcement--> 19
# Legislation on drink driving--> 0
# Drink an drive legislation not validated--> 171
# Alcohol consumption prohibited in country--> 154
# National law on drink-driving--> 1
# BAC limit – general population--> 36
# BAC limit – young or novice drivers--> 37
# Presence of targets to reduce driving after drinking nationally (year)--> 21
# Year by targets to reduce driving after drinking nationally--> 106
# Random breath testing carried out--> 8
# Testing carried out in case of fatal crash--> 12
# Legislation on drug driving--> 0
# Drug and diving legislation not validated--> 171
# Legislation on distracted driving (mobile phones) while driving--> 1
# Distracted driving legislation not validated--> 171
# Ban on mobile phone use (Hand held)--> 23
# Ban on mobile phone use (Hand free)--> 136
# Presence of targets to reduce distracted driving nationally--> 41
# Year by targets to reduce distracted driving nationally (year)--> 117
# Legislation requiring adult motorcycle riders to wear a helmet properly fastened that meets appropriate standards--> 0
# Helmet legislation not validated--> 171
# National motorcycle helmet law--> 1
# Legislation requires helmet fastening--> 1
# Legislation applies to drivers and passengers--> 10
# Legislation applies to all road types--> 0
# Legislation applies to all engine types--> 0
# Legislation refers to and/or specifies helmet standard--> 0
# Helmet standard adheres to corresponding UN or equivalent international safety regulation--> 126
# Helmet standard corresponding EU regulation mandatory for country.--> 146
# Presence of targets to increase helmet use--> 30
# Year by target to increase helmet use--> 104
# Helmet wearing rate (%Driver)--> 101
# Helmet wearing rate (% Passenger)--> 117
# Minimum age/height children are allowed as passengers on motorcycles nationally--> 0
# Legislation on the use of seat belts for all motor vehicle occupants (UNVTI 8a)--> 0
# Seat belt legislation not validated--> 171
# National seat-belt law--> 1
# Legislation applies to front and rear seat occupants--> 11
# Presence of targets to increase seat belt use--> 30
# Year by target to increase seat belt use (year)--> 101
# Seat-belt wearing rate  (% Drivers)--> 97
# Seat-belt wearing rate (% front seat occupants)--> 112
# Seat-belt wearing rate  (% rear seat occupants)--> 131
# Legislation requiring the use of child safety restraint systems that meet appropriate standards--> 0
# CRS legislation not validated--> 171
# National child restraints use law--> 1
# Children seated in front seat--> 0
# Age or height specified for children requiring child restraint--> 92
# Child restraint standard referred to and/or specified--> 0
# CRS standard adheres to corresponding UN or equivalent international safety regulation--> 128
# CRS standard corresponding EU regulation mandatory for country.--> 146
# Presence of targets to increase child safety restraint use--> 33
# Year by targets to increase child safety restraint use--> 119
# Civil Registration and Vital Statistics level--> 1
# Evolution of frequency and distribution of journeys by modal type--> 29
# Speeding violations and speeding‐related injuries and fatalities--> 16
# Driving under the influence of alcohol or drugs  and related road traffic‐related fatalities and injuries--> 13
# Seat belt  and child-restraint systems use--> 19
# Powered 2- and 3- wheeler helmet use--> 18
# Mobile phone use while driving--> 19
# Evolution of population--> 0
# Evolution of income group--> 5
# Evolution of reported fatalities--> 4
# Evolution of WHO-estimated fatalities--> 8
# Evolution of WHO-estimated fatality rate--> 8
# Evolution of presence of systematic approaches to assess/audit new roads--> 19
# Evolution of investments to upgrade high risk locations--> 42
# Evolution of total registered vehicles--> 38
# Evolution of cars and 4-wheeled light vehicles--> 74
# Evolution of powered 2- and 3-wheelers--> 72
# Evolution of heavy trucks--> 71
# Evolution of buses--> 72
# Evolution of other--> 104
# Evolution of national emergency care access number--> 45
# Evolution of strategies to promote alternatives to individuals' use of powered vehicles--> 28
# Evolution of National road safety strategy--> 28
# Evolution of fatality reduction target--> 64
# Evolution of non fatal reduction target--> 59
# Evolution of national lead agency to implement  national road safety action plan--> 5
# Evolution Legislation setting appropriate urban speed limits for passenger cars and motorcycles--> 3
# Evolution of national law setting a speed limit  --> 5
# Evolution of maximum urban speed limit--> 19
# Evolution of maximum rural speed limit--> 19
# Evolution of maximum motorway speed limit--> 53
# Evolution of whether local authorities can modify limits--> 89
# Evolution of available types of enforcement--> 18
# Evolution of legislation on drink driving--> 3
# Evolution of national law on drink-driving--> 1
# Evolution of BAC limit – general population--> 40
# Evolution of BAC limit – young or novice drivers--> 40
# Evolution of Random breath testing carried out--> 8
# Evolution of Testing carried out in case of fatal crash--> 12
# Evolution of Legislation on drug driving--> 3
# Evolution of Legislation on distracted driving (mobile phones) while driving--> 3
# Evolution on ban on mobile phone use--> 1
# Evolution of Legislation requiring adult motorcycle riders to wear a helmet properly fastened that meets appropriate standards--> 3
# Evolution of National motorcycle helmet law--> 2
# Evolution of presence of targets to reduce driving after drinking nationally--> 0
# Evolution of legislation applies to drivers and passengers--> 3
# Evolution of legislation applies to all road types--> 0
# Evolution of legislation applies to all engine types--> 0
# Evolution of legislation refers to and/or specifies helmet standard--> 0
# Evolution of Helmet wearing rate--> 153
# Evolution of minimum age/height children are allowed as passengers on motorcycles nationally--> 0
# Evolution of legislation on the use of seat belts for all motor vehicle occupants--> 3
# Evolution of national seat-belt law--> 1
# Evolution of legislation applies to front and rear seat occupants--> 0
# Evolution of seat-belt wearing rate--> 158
# Evolution of legislation requiring the use of child safety restraint systems that meet appropriate standards--> 3
# Evolution of national child restraints use law--> 1
# Evolution of children seated in front seat--> 0
# Evolution of age or height specified for children requiring child restraint--> 4
# Evolution of child restraint standard referred to and/or specified--> 0
# Evolution in Civil Registration and Vital Statistics qualification--> 1
# Item not collected before--> 172
# Evolution in adhesion UN conventions--> 0
# Year WHO-estimated road traffic fatalities (Update)--> 0
# 2010 WHO-estimated road traffic fatalities (update)--> 1
# 2010 Lower bound WHO-estimated road traffic fatalities (update)--> 1
# 2010 Upper bound WHO-estimated road traffic fatalities (update)--> 1
# 2010 WHO-estimated rate per 100 000 population (update)--> 1
# Year WHO-estimated road traffic fatalities (Update).1--> 0
# 2016 WHO-estimated road traffic fatalities (update)--> 1
# 2016 Lower bound WHO-estimated road traffic fatalities (update)--> 2
# 2016 Upper bound WHO-estimated road traffic fatalities (update)--> 2
# 2016 WHO-estimated rate per 100 000 population (update)--> 1

# %%
data.describe()
# Out:
#          Population  GRSSR participation 2009  GRSSR participation 2013  \
# count  1.720000e+02                     160.0                     164.0
# mean   4.489477e+07                    2009.0                    2013.0
# std    1.574633e+08                       0.0                       0.0
# min    1.937000e+03                    2009.0                    2013.0
# 25%    2.847956e+06                    2009.0                    2013.0
# 50%    1.028422e+07                    2009.0                    2013.0
# 75%    3.312970e+07                    2009.0                    2013.0
# max    1.425893e+09                    2009.0                    2013.0
#
#        GRSSR participation 2015  GRSSR participation 2018  \
# count                     164.0                     162.0
# mean                     2015.0                    2018.0
# std                         0.0                       0.0
# min                      2015.0                    2018.0
# 25%                      2015.0                    2018.0
# 50%                      2015.0                    2018.0
# 75%                      2015.0                    2018.0
# max                      2015.0                    2018.0
#
#        GRSSR participation 2013.1  Reported fatalities  \
# count                       172.0           171.000000
# mean                       2023.0          3519.807018
# std                           0.0         13472.390860
# min                        2023.0             0.000000
# 25%                        2023.0           154.500000
# 50%                        2023.0           561.000000
# 75%                        2023.0          2257.500000
# max                        2023.0        153972.000000
#
#        Year reported fatalities  \
# count                172.000000
# mean                2020.918605
# std                    0.381291
# min                 2018.000000
# 25%                 2021.000000
# 50%                 2021.000000
# 75%                 2021.000000
# max                 2022.000000
#
#        Reported fatalities gender distribution  (% Males)  \
# count                                         134.000000
# mean                                           76.788209
# std                                            14.247971
# min                                             7.100000
# 25%                                            74.430000
# 50%                                            79.000000
# 75%                                            84.900000
# max                                           100.000000
#
#        Reported fatalities gender distribution  (%Females)  ...  \
# count                                         133.000000    ...
# mean                                           22.734436    ...
# std                                            13.747091    ...
# min                                             1.000000    ...
# 25%                                            15.000000    ...
# 50%                                            20.740000    ...
# 75%                                            25.000000    ...
# max                                            92.900000    ...
#
#        Year WHO-estimated road traffic fatalities (Update)  \
# count                                              172.0
# mean                                              2010.0
# std                                                  0.0
# min                                               2010.0
# 25%                                               2010.0
# 50%                                               2010.0
# 75%                                               2010.0
# max                                               2010.0
#
#        2010 WHO-estimated road traffic fatalities (update)  \
# count                                         171.000000
# mean                                         7143.725146
# std                                         27358.533191
# min                                             0.000000
# 25%                                           333.000000
# 50%                                          1413.000000
# 75%                                          4436.000000
# max                                        279005.000000
#
#        2010 Lower bound WHO-estimated road traffic fatalities (update)  \
# count                                         171.000000
# mean                                         6370.643275
# std                                         24627.918603
# min                                             0.000000
# 25%                                           311.500000
# 50%                                          1181.000000
# 75%                                          3954.000000
# max                                        253877.000000
#
#        2010 Upper bound WHO-estimated road traffic fatalities (update)  \
# count                                         171.000000
# mean                                         7916.742690
# std                                         30097.493766
# min                                             0.000000
# 25%                                           367.000000
# 50%                                          1497.000000
# 75%                                          4857.000000
# max                                        304133.000000
#
#        2010 WHO-estimated rate per 100 000 population (update)  \
# count                                         171.000000
# mean                                           16.630409
# std                                             8.351704
# min                                             0.000000
# 25%                                            10.550000
# 50%                                            16.600000
# 75%                                            22.400000
# max                                            45.800000
#
#        Year WHO-estimated road traffic fatalities (Update).1  \
# count                                              172.0
# mean                                              2016.0
# std                                                  0.0
# min                                               2016.0
# 25%                                               2016.0
# 50%                                               2016.0
# 75%                                               2016.0
# max                                               2016.0
#
#        2016 WHO-estimated road traffic fatalities (update)  \
# count                                         171.000000
# mean                                         6899.578947
# std                                         25534.102906
# min                                             0.000000
# 25%                                           335.000000
# 50%                                          1307.000000
# 75%                                          4534.500000
# max                                        256180.000000
#
#        2016 Lower bound WHO-estimated road traffic fatalities (update)  \
# count                                         170.000000
# mean                                         6218.523529
# std                                         23439.775293
# min                                             0.000000
# 25%                                           311.750000
# 50%                                          1203.000000
# 75%                                          3816.250000
# max                                        238827.000000
#
#        2016 Upper bound WHO-estimated road traffic fatalities (update)  \
# count                                         170.000000
# mean                                         7661.688235
# std                                         27782.583326
# min                                             0.000000
# 25%                                           363.500000
# 50%                                          1452.500000
# 75%                                          5346.250000
# max                                        273533.000000
#
#        2016 WHO-estimated rate per 100 000 population (update)
# count                                         171.000000
# mean                                           15.291228
# std                                             8.110428
# min                                             0.000000
# 25%                                             8.600000
# 50%                                            15.200000
# 75%                                            20.750000
# max                                            39.600000
#
# [8 rows x 97 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
missing_percent = data.isnull().mean() * 100
high_missing = missing_percent[missing_percent >= 75]
print("Columns with ≥75% missing values and their percentages:")
print(high_missing.sort_values(ascending=False))
# Out:
# Columns with ≥75% missing values and their percentages:
# Item not collected before                                                                                                100.000000
# VTI legislation not validated                                                                                            100.000000
# Drink an drive legislation not validated                                                                                  99.418605
# CRS legislation not validated                                                                                             99.418605
# Seat belt legislation not validated                                                                                       99.418605
# Helmet legislation not validated                                                                                          99.418605
# Distracted driving legislation not validated                                                                              99.418605
# Drug and diving legislation not validated                                                                                 99.418605
# Speed legislation not validated                                                                                           98.837209
# Legislation on road inspection/assessment not validated                                                                   98.255814
# Evolution of seat-belt wearing rate                                                                                       91.860465
# On VTI country adheres to corresponding UN or equivalent international safety regulation                                  91.860465
# Alcohol consumption prohibited in country                                                                                 89.534884
# Evolution of Helmet wearing rate                                                                                          88.953488
# Insurance legislation not validated                                                                                       87.209302
# On driving time legislation  not validated                                                                                87.209302
# Front and side impact protection legislation not validated                                                                85.465116
# On ESC corresponding EU regulation mandatory for country.                                                                 84.883721
# Helmet standard corresponding EU regulation mandatory for country.                                                        84.883721
# CRS standard corresponding EU regulation mandatory for country.                                                           84.883721
# On VTI corresponding EU regulation mandatory for country.                                                                 84.883721
# On front and side impact protection corresponding EU regulation mandatory for country.                                    84.883721
# On pedestrian protection corresponding EU regulation mandatory for country.                                               84.883721
# Corresponding EU regulation mandatory for country.                                                                        84.883721
# Unnamed: 87                                                                                                               84.883721
# On ABS corresponding EU regulation mandatory for country.                                                                 84.883721
# Ban on mobile phone use (Hand free)                                                                                       79.069767
# National target for time between serious crash and initial provision of professional emergency care                       79.069767
# On front and side impact protection country adheres to corresponding UN or equivalent international safety regulation     76.744186
# Seat-belt wearing rate  (% rear seat occupants)                                                                           76.162791
# dtype: float64

# %%
print("Before:", data.shape)
df = data.drop(columns=data.columns[data.isnull().mean() >= 0.75])
print("After:", df.shape)
# Out:
# Before: (172, 228)
# After: (172, 198)

# %%
for col in df.columns:
    print(col)
# Out:
# WHO status
# ISO_3 country name
# Country name
# Population
# Income group
# WHO Region
# GRSSR participation 2009
# GRSSR participation 2013
# GRSSR participation 2015
# GRSSR participation 2018
# GRSSR participation 2013.1
# Reported fatalities
# Year reported fatalities
# Reported fatalities gender distribution  (% Males)
# Reported fatalities gender distribution  (%Females)
# Reported fatalities user distribution  (% powered light vehicles)
# Reported fatalities user distribution  (% powered 2/ wheelers)
# Reported fatalities user distribution  (% pedestrian)
# Reported fatalities user distribution  (% cyclist)
# Reported fatalities user distribution  (% other)
# WHO-estimated road traffic fatalities
# Lower bound WHO-estimated road traffic fatalities
# Upper bound WHO-estimated road traffic fatalities
# Year WHO-estimated road traffic fatalities
# WHO-estimated rate per 100 000 population
# National law on universal access to emergency care
# emergency care access legislation not validated
# National law guaranteeing free-of-charge access to rehabilitative care for all injured
# Access to rehab care legislation not validated
# National law guaranteeing free-of-charge access to psychological services to road crash victims and their families
# Psychological care access legislation not validated
# National good Samaritan law
# Good Samaritan law not validated
# National emergency care access number
# Year by National target for time between serious crash and initial provision of professional emergency care (year)
# Total paved kilometres (year)
# Year total paved kilometres
# Presence of technical standards for new roads that take account of all road-user safety, or align with relevant UN Conventions and regulate compliance with them
# On roads technical standards country adheres to corresponding UN or equivalent international safety regulation
# Presence of systematic approaches to assess/audit new roads
# National law requiring a formal road safety inspection/assessment
# Target for roads to meet technical safety standards for all users
# Year by target for roads to meet technical safety standards for all users (year)
# Investments to upgrade high risk locations
# Total registered vehicles
# Total registered vehicles rate per 100 000 pop
# Cars and 4-wheeled light vehicles
# Powered 2- and 3-wheelers
# Heavy trucks
# Buses
# Other
# Legislation on periodic vehicle technical inspection
# Year total registered vehicles
# Presence of high-quality safety standards for used-vehicle imports/exports 2
# National law on front and side impact protection
# National law on seat belt and seat belt anchorages
# Country adheres to corresponding UN or equivalent international safety regulation
# National law on electronic stability control
# On ESC country adheres to corresponding UN or equivalent international safety regulation
# National law on pedestrian protection
# On pedestrian protection country adheres to corresponding UN or equivalent international safety regulation
# National law on motorcycle anti-lock braking systems
# On ABS country adheres to corresponding UN or equivalent international safety regulation
# Government vehicle procurement practices include safety prerequisites
# Presence of strategies to promote alternatives to individuals' use of powered vehicles
# National road safety strategy
# Fatality reduction target
# Year by fatality reduction target
# Non fatal reduction target (year)
# Year by non fatal reduction target
# Funding to implement strategy
# National legislation mandating third-party liability insurance for powered vehicles
# National law on driving time and rest periods for professional drivers
# On driving time legislation country adheres to corresponding UN or equivalent international safety regulation
# Adhesion to at least one of the 7 UN core vehicle regulations
# Adherence to one or more of the 7 UN road safety conventions
# Presence of national lead agency to implement  national road safety action plan
# Presence of agencies that  coordinate pre‐hospital and emergency medical services
# Legislation setting appropriate urban speed limits for passenger cars and motorcycles
# National law setting a speed limit
# Maximum urban speed limit
# Maximum rural speed limit
# Maximum motorway speed limit
# Local authorities can modify limits
# Presence of targets to reduce speeds nationally
# Year by targets to reduce speeds nationally
# Available types of enforcement
# Legislation on drink driving
# National law on drink-driving
# BAC limit – general population
# BAC limit – young or novice drivers
# Presence of targets to reduce driving after drinking nationally (year)
# Year by targets to reduce driving after drinking nationally
# Random breath testing carried out
# Testing carried out in case of fatal crash
# Legislation on drug driving
# Legislation on distracted driving (mobile phones) while driving
# Ban on mobile phone use (Hand held)
# Presence of targets to reduce distracted driving nationally
# Year by targets to reduce distracted driving nationally (year)
# Legislation requiring adult motorcycle riders to wear a helmet properly fastened that meets appropriate standards
# National motorcycle helmet law
# Legislation requires helmet fastening
# Legislation applies to drivers and passengers
# Legislation applies to all road types
# Legislation applies to all engine types
# Legislation refers to and/or specifies helmet standard
# Helmet standard adheres to corresponding UN or equivalent international safety regulation
# Presence of targets to increase helmet use
# Year by target to increase helmet use
# Helmet wearing rate (%Driver)
# Helmet wearing rate (% Passenger)
# Minimum age/height children are allowed as passengers on motorcycles nationally
# Legislation on the use of seat belts for all motor vehicle occupants (UNVTI 8a)
# National seat-belt law
# Legislation applies to front and rear seat occupants
# Presence of targets to increase seat belt use
# Year by target to increase seat belt use (year)
# Seat-belt wearing rate  (% Drivers)
# Seat-belt wearing rate (% front seat occupants)
# Legislation requiring the use of child safety restraint systems that meet appropriate standards
# National child restraints use law
# Children seated in front seat
# Age or height specified for children requiring child restraint
# Child restraint standard referred to and/or specified
# CRS standard adheres to corresponding UN or equivalent international safety regulation
# Presence of targets to increase child safety restraint use
# Year by targets to increase child safety restraint use
# Civil Registration and Vital Statistics level
# Evolution of frequency and distribution of journeys by modal type
# Speeding violations and speeding‐related injuries and fatalities
# Driving under the influence of alcohol or drugs  and related road traffic‐related fatalities and injuries
# Seat belt  and child-restraint systems use
# Powered 2- and 3- wheeler helmet use
# Mobile phone use while driving
# Evolution of population
# Evolution of income group
# Evolution of reported fatalities
# Evolution of WHO-estimated fatalities
# Evolution of WHO-estimated fatality rate
# Evolution of presence of systematic approaches to assess/audit new roads
# Evolution of investments to upgrade high risk locations
# Evolution of total registered vehicles
# Evolution of cars and 4-wheeled light vehicles
# Evolution of powered 2- and 3-wheelers
# Evolution of heavy trucks
# Evolution of buses
# Evolution of other
# Evolution of national emergency care access number
# Evolution of strategies to promote alternatives to individuals' use of powered vehicles
# Evolution of National road safety strategy
# Evolution of fatality reduction target
# Evolution of non fatal reduction target
# Evolution of national lead agency to implement  national road safety action plan
# Evolution Legislation setting appropriate urban speed limits for passenger cars and motorcycles
# Evolution of national law setting a speed limit
# Evolution of maximum urban speed limit
# Evolution of maximum rural speed limit
# Evolution of maximum motorway speed limit
# Evolution of whether local authorities can modify limits
# Evolution of available types of enforcement
# Evolution of legislation on drink driving
# Evolution of national law on drink-driving
# Evolution of BAC limit – general population
# Evolution of BAC limit – young or novice drivers
# Evolution of Random breath testing carried out
# Evolution of Testing carried out in case of fatal crash
# Evolution of Legislation on drug driving
# Evolution of Legislation on distracted driving (mobile phones) while driving
# Evolution on ban on mobile phone use
# Evolution of Legislation requiring adult motorcycle riders to wear a helmet properly fastened that meets appropriate standards
# Evolution of National motorcycle helmet law
# Evolution of presence of targets to reduce driving after drinking nationally
# Evolution of legislation applies to drivers and passengers
# Evolution of legislation applies to all road types
# Evolution of legislation applies to all engine types
# Evolution of legislation refers to and/or specifies helmet standard
# Evolution of minimum age/height children are allowed as passengers on motorcycles nationally
# Evolution of legislation on the use of seat belts for all motor vehicle occupants
# Evolution of national seat-belt law
# Evolution of legislation applies to front and rear seat occupants
# Evolution of legislation requiring the use of child safety restraint systems that meet appropriate standards
# Evolution of national child restraints use law
# Evolution of children seated in front seat
# Evolution of age or height specified for children requiring child restraint
# Evolution of child restraint standard referred to and/or specified
# Evolution in Civil Registration and Vital Statistics qualification
# Evolution in adhesion UN conventions
# Year WHO-estimated road traffic fatalities (Update)
# 2010 WHO-estimated road traffic fatalities (update)
# 2010 Lower bound WHO-estimated road traffic fatalities (update)
# 2010 Upper bound WHO-estimated road traffic fatalities (update)
# 2010 WHO-estimated rate per 100 000 population (update)
# Year WHO-estimated road traffic fatalities (Update).1
# 2016 WHO-estimated road traffic fatalities (update)
# 2016 Lower bound WHO-estimated road traffic fatalities (update)
# 2016 Upper bound WHO-estimated road traffic fatalities (update)
# 2016 WHO-estimated rate per 100 000 population (update)

# %%
df.columns = df.columns.str.strip()  # removes leading/trailing spaces

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
for col in df.columns:
    print(col)
# Out:
# who_status
# iso_3_country_name
# country_name
# population
# income_group
# who_region
# grssr_participation_2009
# grssr_participation_2013
# grssr_participation_2015
# grssr_participation_2018
# grssr_participation_2013.1
# reported_fatalities
# year_reported_fatalities
# reported_fatalities_gender_distribution__(%_males)
# reported_fatalities_gender_distribution__(%females)
# reported_fatalities_user_distribution__(%_powered_light_vehicles)
# reported_fatalities_user_distribution__(%_powered_2/_wheelers)
# reported_fatalities_user_distribution__(%_pedestrian)
# reported_fatalities_user_distribution__(%_cyclist)
# reported_fatalities_user_distribution__(%_other)
# who-estimated_road_traffic_fatalities
# lower_bound_who-estimated_road_traffic_fatalities
# upper_bound_who-estimated_road_traffic_fatalities
# year_who-estimated_road_traffic_fatalities
# who-estimated_rate_per_100_000_population
# national_law_on_universal_access_to_emergency_care
# emergency_care_access_legislation_not_validated
# national_law_guaranteeing_free-of-charge_access_to_rehabilitative_care_for_all_injured
# access_to_rehab_care_legislation_not_validated
# national_law_guaranteeing_free-of-charge_access_to_psychological_services_to_road_crash_victims_and_their_families
# psychological_care_access_legislation_not_validated
# national_good_samaritan_law
# good_samaritan_law_not_validated
# national_emergency_care_access_number
# year_by_national_target_for_time_between_serious_crash_and_initial_provision_of_professional_emergency_care_(year)
# total_paved_kilometres_(year)
# year_total_paved_kilometres
# presence_of_technical_standards_for_new_roads_that_take_account_of_all_road-user_safety,_or_align_with_relevant_un_conventions_and_regulate_compliance_with_them
# on_roads_technical_standards_country_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# presence_of_systematic_approaches_to_assess/audit_new_roads
# national_law_requiring_a_formal_road_safety_inspection/assessment
# target_for_roads_to_meet_technical_safety_standards_for_all_users
# year_by_target_for_roads_to_meet_technical_safety_standards_for_all_users_(year)
# investments_to_upgrade_high_risk_locations
# total_registered_vehicles
# total_registered_vehicles_rate_per_100_000_pop
# cars_and_4-wheeled_light_vehicles
# powered_2-_and_3-wheelers
# heavy_trucks
# buses
# other
# legislation_on_periodic_vehicle_technical_inspection
# year_total_registered_vehicles
# presence_of_high-quality_safety_standards_for_used-vehicle_imports/exports_2
# national_law_on_front_and_side_impact_protection
# national_law_on_seat_belt_and_seat_belt_anchorages
# country_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# national_law_on_electronic_stability_control
# on_esc_country_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# national_law_on_pedestrian_protection
# on_pedestrian_protection_country_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# national_law_on_motorcycle_anti-lock_braking_systems
# on_abs_country_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# government_vehicle_procurement_practices_include_safety_prerequisites
# presence_of_strategies_to_promote_alternatives_to_individuals'_use_of_powered_vehicles
# national_road_safety_strategy
# fatality_reduction_target
# year_by_fatality_reduction_target
# non_fatal_reduction_target_(year)
# year_by_non_fatal_reduction_target
# funding_to_implement_strategy
# national_legislation_mandating_third-party_liability_insurance_for_powered_vehicles
# national_law_on_driving_time_and_rest_periods_for_professional_drivers
# on_driving_time_legislation_country_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# adhesion_to_at_least_one_of_the_7_un_core_vehicle_regulations
# adherence_to_one_or_more_of_the_7_un_road_safety_conventions
# presence_of_national_lead_agency_to_implement__national_road_safety_action_plan
# presence_of_agencies_that__coordinate_pre‐hospital_and_emergency_medical_services
# legislation_setting_appropriate_urban_speed_limits_for_passenger_cars_and_motorcycles
# national_law_setting_a_speed_limit
# maximum_urban_speed_limit
# maximum_rural_speed_limit
# maximum_motorway_speed_limit
# local_authorities_can_modify_limits
# presence_of_targets_to_reduce_speeds_nationally
# year_by_targets_to_reduce_speeds_nationally
# available_types_of_enforcement
# legislation_on_drink_driving
# national_law_on_drink-driving
# bac_limit_–_general_population
# bac_limit_–_young_or_novice_drivers
# presence_of_targets_to_reduce_driving_after_drinking_nationally_(year)
# year_by_targets_to_reduce_driving_after_drinking_nationally
# random_breath_testing_carried_out
# testing_carried_out_in_case_of_fatal_crash
# legislation_on_drug_driving
# legislation_on_distracted_driving_(mobile_phones)_while_driving
# ban_on_mobile_phone_use_(hand_held)
# presence_of_targets_to_reduce_distracted_driving_nationally
# year_by_targets_to_reduce_distracted_driving_nationally_(year)
# legislation_requiring_adult_motorcycle_riders_to_wear_a_helmet_properly_fastened_that_meets_appropriate_standards
# national_motorcycle_helmet_law
# legislation_requires_helmet_fastening
# legislation_applies_to_drivers_and_passengers
# legislation_applies_to_all_road_types
# legislation_applies_to_all_engine_types
# legislation_refers_to_and/or_specifies_helmet_standard
# helmet_standard_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# presence_of_targets_to_increase_helmet_use
# year_by_target_to_increase_helmet_use
# helmet_wearing_rate_(%driver)
# helmet_wearing_rate_(%_passenger)
# minimum_age/height_children_are_allowed_as_passengers_on_motorcycles_nationally
# legislation_on_the_use_of_seat_belts_for_all_motor_vehicle_occupants_(unvti_8a)
# national_seat-belt_law
# legislation_applies_to_front_and_rear_seat_occupants
# presence_of_targets_to_increase_seat_belt_use
# year_by_target_to_increase_seat_belt_use_(year)
# seat-belt_wearing_rate__(%_drivers)
# seat-belt_wearing_rate_(%_front_seat_occupants)
# legislation_requiring_the_use_of_child_safety_restraint_systems_that_meet_appropriate_standards
# national_child_restraints_use_law
# children_seated_in_front_seat
# age_or_height_specified_for_children_requiring_child_restraint
# child_restraint_standard_referred_to_and/or_specified
# crs_standard_adheres_to_corresponding_un_or_equivalent_international_safety_regulation
# presence_of_targets_to_increase_child_safety_restraint_use
# year_by_targets_to_increase_child_safety_restraint_use
# civil_registration_and_vital_statistics_level
# evolution_of_frequency_and_distribution_of_journeys_by_modal_type
# speeding_violations_and_speeding‐related_injuries_and_fatalities
# driving_under_the_influence_of_alcohol_or_drugs__and_related_road_traffic‐related_fatalities_and_injuries
# seat_belt__and_child-restraint_systems_use
# powered_2-_and_3-_wheeler_helmet_use
# mobile_phone_use_while_driving
# evolution_of_population
# evolution_of_income_group
# evolution_of_reported_fatalities
# evolution_of_who-estimated_fatalities
# evolution_of_who-estimated_fatality_rate
# evolution_of_presence_of_systematic_approaches_to_assess/audit_new_roads
# evolution_of_investments_to_upgrade_high_risk_locations
# evolution_of_total_registered_vehicles
# evolution_of_cars_and_4-wheeled_light_vehicles
# evolution_of_powered_2-_and_3-wheelers
# evolution_of_heavy_trucks
# evolution_of_buses
# evolution_of_other
# evolution_of_national_emergency_care_access_number
# evolution_of_strategies_to_promote_alternatives_to_individuals'_use_of_powered_vehicles
# evolution_of_national_road_safety_strategy
# evolution_of_fatality_reduction_target
# evolution_of_non_fatal_reduction_target
# evolution_of_national_lead_agency_to_implement__national_road_safety_action_plan
# evolution_legislation_setting_appropriate_urban_speed_limits_for_passenger_cars_and_motorcycles
# evolution_of_national_law_setting_a_speed_limit
# evolution_of_maximum_urban_speed_limit
# evolution_of_maximum_rural_speed_limit
# evolution_of_maximum_motorway_speed_limit
# evolution_of_whether_local_authorities_can_modify_limits
# evolution_of_available_types_of_enforcement
# evolution_of_legislation_on_drink_driving
# evolution_of_national_law_on_drink-driving
# evolution_of_bac_limit_–_general_population
# evolution_of_bac_limit_–_young_or_novice_drivers
# evolution_of_random_breath_testing_carried_out
# evolution_of_testing_carried_out_in_case_of_fatal_crash
# evolution_of_legislation_on_drug_driving
# evolution_of_legislation_on_distracted_driving_(mobile_phones)_while_driving
# evolution_on_ban_on_mobile_phone_use
# evolution_of_legislation_requiring_adult_motorcycle_riders_to_wear_a_helmet_properly_fastened_that_meets_appropriate_standards
# evolution_of_national_motorcycle_helmet_law
# evolution_of_presence_of_targets_to_reduce_driving_after_drinking_nationally
# evolution_of_legislation_applies_to_drivers_and_passengers
# evolution_of_legislation_applies_to_all_road_types
# evolution_of_legislation_applies_to_all_engine_types
# evolution_of_legislation_refers_to_and/or_specifies_helmet_standard
# evolution_of_minimum_age/height_children_are_allowed_as_passengers_on_motorcycles_nationally
# evolution_of_legislation_on_the_use_of_seat_belts_for_all_motor_vehicle_occupants
# evolution_of_national_seat-belt_law
# evolution_of_legislation_applies_to_front_and_rear_seat_occupants
# evolution_of_legislation_requiring_the_use_of_child_safety_restraint_systems_that_meet_appropriate_standards
# evolution_of_national_child_restraints_use_law
# evolution_of_children_seated_in_front_seat
# evolution_of_age_or_height_specified_for_children_requiring_child_restraint
# evolution_of_child_restraint_standard_referred_to_and/or_specified
# evolution_in_civil_registration_and_vital_statistics_qualification
# evolution_in_adhesion_un_conventions
# year_who-estimated_road_traffic_fatalities_(update)
# 2010_who-estimated_road_traffic_fatalities_(update)
# 2010_lower_bound_who-estimated_road_traffic_fatalities_(update)
# 2010_upper_bound_who-estimated_road_traffic_fatalities_(update)
# 2010_who-estimated_rate_per_100_000_population_(update)
# year_who-estimated_road_traffic_fatalities_(update).1
# 2016_who-estimated_road_traffic_fatalities_(update)
# 2016_lower_bound_who-estimated_road_traffic_fatalities_(update)
# 2016_upper_bound_who-estimated_road_traffic_fatalities_(update)
# 2016_who-estimated_rate_per_100_000_population_(update)

# %%
law_columns = [
    'national_motorcycle_helmet_law',
    'national_seat-belt_law',
    'national_child_restraints_use_law',
    'national_law_setting_a_speed_limit'
]

for col in law_columns:
    df[col + '_bool'] = df[col].str.strip().str.lower() == 'yes'

df['has_all_key_laws'] = (
    df['national_motorcycle_helmet_law_bool'] &
    df['national_seat-belt_law_bool'] &
    df['national_child_restraints_use_law_bool'] &
    df['national_law_setting_a_speed_limit_bool']
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 8))
plt.bar(df['country_name'], df['population'] / 1_000_000, color='green')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population (in millions)')
plt.title('Population by Country')
plt.tight_layout()
plt.show()

# %%
top_10_fatalities = df[['country_name', 'reported_fatalities']].sort_values(by='reported_fatalities', ascending=False).head(10)

# Create the bar chart
plt.figure(figsize=(12, 8))
bars = plt.barh(top_10_fatalities['country_name'], top_10_fatalities['reported_fatalities'], color='red')

# Add the numbers on the bars
for bar in bars:
    plt.text(bar.get_width() + 500, bar.get_y() + bar.get_height() / 2,
             f'{bar.get_width():,.0f}',  # Format the number with commas for thousands
             va='center', ha='left', fontsize=10)

plt.xlabel('Reported Fatalities')
plt.ylabel('Country')
plt.title('Top 10 Countries by Reported Fatalities')
plt.gca().invert_yaxis()  # Invert to display the country with the highest fatalities at the top
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='population', y='reported_fatalities')
plt.xscale('log')
plt.title('Population vs reported_fatalities')
plt.xlabel('Population (log scale)')
plt.ylabel('reported_fatalities')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
top10 = df.nlargest(10, 'year_by_fatality_reduction_target')

# Plot
plt.figure(figsize=(12, 6))
bars = plt.bar(top10['country_name'], top10['year_by_fatality_reduction_target'], color='purple')
plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Year by fatality reduction target')
plt.title('Top 10 Countries of year by fatality reduction target')
# Add labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2,
             height,
             f'{height:.1f}',
             ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='has_all_key_laws', y= df['who-estimated_rate_per_100_000_population'])
plt.title('Key Law presence vs Road Fatality Rate')
plt.xlabel('The key Laws Exists')
plt.ylabel('Fatality Rate per 100,000')
plt.tight_layout()
plt.show()

# %%
df['national_road_safety_strategy'].value_counts()
# Out:
# national_road_safety_strategy
# Yes            126
# No              36
# Subnational      1
# Local            1
# Name: count, dtype: int64

# %%
# Step 1: Set a threshold for low-frequency categories
threshold = 2  # You can change this based on your dataset size

# Step 2: Get value counts and identify rare categories
value_counts = df['national_road_safety_strategy'].value_counts()
to_remove = value_counts[value_counts < threshold].index

# Step 3: Remove rows with those rare categories (optional)
df = df[~df['national_road_safety_strategy'].isin(to_remove)]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='national_road_safety_strategy', y='who-estimated_rate_per_100_000_population')
plt.title('Road Safety Strategy Presence vs Fatality Rate')
plt.xlabel('Road Safety Strategy Exists')
plt.ylabel('Estimated Fatality Rate per 100,000')
plt.tight_layout()
plt.show()

# %%
years = ['grssr_participation_2009', 'grssr_participation_2013', 
         'grssr_participation_2015', 'grssr_participation_2018']
participation = df[years].count()

ax = participation.plot(kind='bar', color='orange')
plt.title('Country Participation in Global Road Safety Status Reports')
plt.xlabel('Year')
plt.ylabel('Number of Participating Countries')
plt.xticks(rotation=0)

# Annotate each bar
for bar in ax.patches:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2,
            height,
            f'{height:.1f}',
            ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()
